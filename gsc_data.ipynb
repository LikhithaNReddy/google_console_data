# %%
creds = 'client_secret.json'
# https://www.jcchouinard.com/google-api/

site = 'https://www.jcchouinard.com'
start_date = '2022-01-01' 
end_date = '2020-01-30' # Default: 3d in past
output = 'gsc_data.csv'

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached certifi-2020.4.5.1-py2.py3-none-any.whl (157 kB)
# ...
#   Using cached google_api_python_client-1.8.3-py3-none-any.whl (58 kB)
# ...
#   Using cached google_auth-1.15.0-py2.py3-none-any.whl (89 kB)
# ...
#   Using cached google_auth_httplib2-0.0.3-py2.py3-none-any.whl (6.3 kB)
# ...
#   Using cached google_auth_oauthlib-0.4.1-py2.py3-none-any.whl (18 kB)
# ...
#   Using cached httplib2-0.18.1-py3-none-any.whl (95 kB)
# ...
#   Using cached idna-2.6-py2.py3-none-any.whl (56 kB)
# ...
#   Using cached oauth2client-4.1.2-py2.py3-none-any.whl (99 kB)
# ...
#   Using cached oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# ...
#   Using cached pyasn1-0.4.2-py2.py3-none-any.whl (71 kB)
# ...
#   Using cached pyasn1_modules-0.2.1-py2.py3-none-any.whl (60 kB)
# ...
#   Using cached requests-2.23.0-py2.py3-none-any.whl (58 kB)
# ...
#   Using cached requests_oauthlib-0.8.0-py2.py3-none-any.whl (23 kB)
# ...
#   Using cached rsa-3.4.2-py2.py3-none-any.whl (46 kB)
# ...
#   Using cached uritemplate-3.0.0-py2.py3-none-any.whl (10 kB)
# ...

# %%
from oauth import authorize_creds

webmasters_service = authorize_creds(creds)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-99dcfba70625> in <module>
# ----> 1 from oauth import authorize_creds
#       2
#       3 webmasters_service = authorize_creds(creds)
#
# ImportError: cannot import name 'authorize_creds' from 'oauth' (/Users/l.reddy/opt/anaconda3/lib/python3.8/site-packages/oauth/__init__.py)
